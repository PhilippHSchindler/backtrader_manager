# %% [markdown]
# # Imports

# %%
# %matplotlib qt 
import pandas as pd
import backtrader_manager as bm

# %%
# the classes defining the backtests can be found in Bitcoin.py
from Bitcoin import (
    BenchmarkBitcoinStrategy,
    BacktestBitcoinStrategy_01, # only macd indicator
    BacktestBitcoinStrategy_02, # macd and atr indicators
    BacktestBitcoinStrategy_03, # macd and ma short/long indicators
    )

# %% [markdown]
# # Instantiate Backtest Collection

# %%
# Path to pandas ohlc data
csv_datas_path = '../../datas/Bitcoin' # in this case relative path, absolute path also possible
# Name of collection
name = 'Main_collection'

# Instantiate new collection
# Or load the collection from harddrive, if it has the same name

main = bm.BacktestCollection(name=name, csv_datas_path=csv_datas_path)
# Out:
# ================================
# Initialising Backtest Collection
# ================================
# ✅ Loaded collection from Main_collection\pkl\collection.pkl

# %% [markdown]
# # Train

# %% [markdown]
# ## Inputs

# %%
# Define backtest class and paramter range for optimisation 
backtest_class = BacktestBitcoinStrategy_01
parameters_macd = {
    'MACD_slow': [20, 60], 
    'MACD_fast': [12, 24], 
    'MACD_SIGNAL': [10, 15] 
}
parameters = parameters_macd

# %%
# Instatiate a new BacktestInputCollection
name_inputs = 'wfo' # wfo for walk forward optimisation

wfo_inputs = bm.BacktestInputCollection(
    name_inputs, # name that decribes type of backtests  
    max_warmup = 200, # maximum bars reserved for any indicator warmup phase prior backtest start
    window=360, # bars used for training periods
    train_perc=0.7, # defines train/test split
    backtest_class=backtest_class, # user defined subclass of bm.backtest
    strategy_parameters=parameters # parameter range of backtrader strategy 
)

# %%
# Add input_collection to backtest_collection
main.add_backtest_input_collection(wfo_inputs)

# %%
# Now we can still play with window size, train_perc and walkforwar_step
# earliest_start and latest end mark the maximum possible timespan that can be used for backtesting across all datafeeds

# %%
wfo_inputs.window = 720

# %%
wfo_inputs.train_perc = 0.7

# %%
wfo_inputs.walkforward_step = int(1 * wfo_inputs.test_window)

# %%
wfo_inputs.calc_train_test_periods()

# %%
wfo_inputs.train_test_periods

# %%
# We can also plot the periods using bars, and if we have multible datafeeds choose which close price to print)
wfo_inputs.plot_train_test_periods(use_dates=False, ref_ticker=None)

# %%
# Now we create the backtest inputs of our walkforward optimisation. 
# Once we did that the train_test_periods can't be changed anymore for this input_collection
# max_chunk_size defines how many runs one single backtrader backtest max. will have

wfo_inputs.create_backtest_inputs(max_chunk_size=5)

# %%
# These are our backtest_input objects that will be used in the following step
# The inputs are not connected to the input_collection, meaning changes applied to any attribute in the input collection 
# won't reflect to these inputs
len(wfo_inputs.backtest_inputs)

# %% [markdown]
# ## Backtests

# %%
# Create backtests using input collection as parameter
main.create_new_backtests(wfo_inputs)

# %%
# This list stores all backtest to be run
len(main.backtests_new)

# %%
main.run_backtests()

# %%
# The completed backtests have been moved to backtests completed
# After every finished backtest the results are stored to harddrive and cerebro result objects are cleared from memory
len(main.backtests_completed)

# %%
# The summary dataframe is the central place to examine and filter the results
# parameter_id: for each backtest_class and parameter combination a parameter_id is assigned
# idx: identifies this specific backtest/run
main.summary.head(10)

# %%
# This view gives a summary overview how the groups of backtest classes and parameter set performed
main.summarize_in_groups(show_parameters=True, sort_by=('sharperatio', 'mean'))

# %%
# Now we add a benchmark and some variations of the first strategy

# %%
parameters_macd

# %%
parameters_ma_short_long = {
    'MA_SHORT': [25, 50],
    'MA_LONG': [100, 150, 200]
}
parameters_atr = {
    'atr_period': [7, 14],
    'atr_threshold': [0.02],
}

# %%
benchmark_class = BenchmarkBitcoinStrategy
parameters_benchmark = None # since its Buy and Hold

# we use same macd parameter ranges for the startegies and add additional filters
backtest_class_02 = BacktestBitcoinStrategy_02
parameters_02 = {**parameters_macd, **parameters_atr} # and add atr parameters

backtest_class_03 = BacktestBitcoinStrategy_03
parameters_03 = {**parameters_macd, **parameters_ma_short_long} # add ma short and long

# %%
# Create backtes inputs for Benchmark 
wfo_inputs.backtest_class = benchmark_class
wfo_inputs.strategy_parameters = parameters_benchmark
wfo_inputs.create_backtest_inputs()

# %%
# Create more backtes inputs
wfo_inputs.backtest_class = backtest_class_02
wfo_inputs.strategy_parameters = parameters_02
wfo_inputs.create_backtest_inputs()

wfo_inputs.backtest_class = backtest_class_03
wfo_inputs.strategy_parameters = parameters_03
wfo_inputs.create_backtest_inputs()

# %%
# now we create all new backtests
main.create_new_backtests(wfo_inputs)

# %%
# this is empty now since we used the inputs to create backtests
wfo_inputs.backtest_inputs

# %%
len(main.backtests_new)

# %%
# Run all new backtests
main.run_backtests()

# %% [markdown]
# ## Selection

# %%
main.summarize()
main.summary

# %%
# metrics of the benchmark over all time periods
main.summarize_in_groups(backtest_class='buy_hold')

# %%
# We sort the groups according to our target metric, in this case mean sharperatio over all periods
# Additionally we show  parameters 
main.summarize_in_groups(sort_by=('sharperatio', 'mean'), show_parameters=True).head(10)

# %%
main.summarize_in_groups(sort_by=('cagr', 'mean')).head(5)

# %%
# We filter for our best ranked group
# We choose a group that performs well in terms of mean sharperatio and mean cagr
backtests_optimum = main.summarize_filter_by(input_collection_name='wfo', parameter_id='strat_03-12', show_parameters=True)

# %%
# We want to inspect the equity curves for each period of our selected group
# Create quantstats reports with benchmark
main.benchmark_class = 'buy_hold'
main.load_all_results() # We first have to load all cerebro result objects from harddrive
main.get_report(summary_filtered=backtests_optimum)

# %% [markdown]
# # Test

# %%
# our selected backtests from train period, that we now want to evaluate in the test period
backtests_optimum

# %%
main.backtest_input_collections[0].create_backtests_train_inputs(summary_filtered=backtests_optimum)

# %%
# Now lets also add our benchmark
backtests_benchmark = main.summarize_filter_by(backtest_class='buy_hold')

# %%
main.backtest_input_collections[0].create_backtests_train_inputs(backtests_benchmark)

# %%
len(main.backtest_input_collections[0].backtest_inputs)
# Out:
# 0

# %%
main.create_new_backtests(main.backtest_input_collections[0])
# Out:
# ======================
# Creating new backtests
# ======================
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 1 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 2 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 3 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 4 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 5 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 6 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 7 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 8 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 9 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 10 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 11 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 12 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 13 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 14 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 15 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 16 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 17 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 18 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 19 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 20 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 21 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 22 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 23 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 24 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 25 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 26 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 27 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 28 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 29 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 30 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 31 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 32 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 33 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 34 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 35 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 36 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 37 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 38 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 39 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 40 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 41 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 42 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 43 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 44 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 45 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 46 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 47 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 48 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 49 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 50 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 51 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 52 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 53 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 54 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 55 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 56 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 57 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 58 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 59 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 60 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 61 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 62 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 63 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 64 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 65 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 66 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 67 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 68 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 69 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 70 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 71 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 72 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 73 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 74 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 75 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 76 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 77 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 78 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 79 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 80 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 81 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 82 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 83 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 84 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 85 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 86 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 87 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 88 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 89 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 90 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 91 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 92 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 93 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 94 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 95 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 96 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 97 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 98 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 99 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 100 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 101 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 102 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 103 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 104 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 105 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 106 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 107 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 108 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 109 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 110 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 111 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 112 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 113 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 114 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 115 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 116 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 117 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 118 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 119 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 120 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 121 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 122 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 123 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 124 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 125 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 126 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 127 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 128 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 129 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 130 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 131 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 132 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 133 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 134 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 135 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 136 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 137 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 138 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 139 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 140 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 141 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 142 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 143 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 144 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 145 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 146 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 147 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 148 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 149 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 150 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 151 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 152 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 153 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 154 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 155 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 156 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 157 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 158 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 159 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 160 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 161 to backtests_new, mode: default
#
# ---------------------
# Initialising Backtest
# ---------------------
# Added backtest 162 to backtests_new, mode: default

# %%
main.run_backtests()
# Out:
# Total number of runs(combinations) to backtest: 162
# Do you want to proceed? (yes/no):  y
# ======================================
# Starting backtest 1/162 with 1 run(s)
#
# ======================================
# Adding strategy datafeeds
# 2019-01-02 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2019-07-21 BACKTEST STARTING
# 2019-08-02 BUY ORDER PLACED
# 2019-08-03 BUY ORDER EXECUTED for BTCUSDT: Price: 10523.75, Value: 9000.00, Comm 4.50
# 2019-08-15 SELL ORDER EXECUTED for BTCUSDT: Price: 10055.16, Value: 9000.00, Comm: 4.30
# 2019-09-03 BUY ORDER PLACED
# 2019-09-04 BUY ORDER EXECUTED for BTCUSDT: Price: 10611.85, Value: 8628.62, Comm 4.31
# 2019-09-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9985.15, Value: 8628.62, Comm: 4.06
# 2019-10-09 BUY ORDER PLACED
# 2019-10-10 BUY ORDER EXECUTED for BTCUSDT: Price: 8562.15, Value: 8166.60, Comm 4.08
# 2020-02-19 SELL ORDER EXECUTED for BTCUSDT: Price: 10164.78, Value: 8166.60, Comm: 4.85
# 2020-02-23 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 10592.168881051784
#
# Finished backtest 1 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ======================================
# Starting backtest 2/162 with 1 run(s)
#
# ======================================
# Adding strategy datafeeds
# 2019-01-02 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2019-07-21 BACKTEST STARTING
# 2019-08-02 BUY ORDER PLACED
# 2019-08-03 BUY ORDER EXECUTED for BTCUSDT: Price: 10523.75, Value: 9000.00, Comm 4.50
# 2019-08-15 SELL ORDER EXECUTED for BTCUSDT: Price: 10055.16, Value: 9000.00, Comm: 4.30
# 2019-09-03 BUY ORDER PLACED
# 2019-09-04 BUY ORDER EXECUTED for BTCUSDT: Price: 10611.85, Value: 8628.62, Comm 4.31
# 2019-09-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9985.15, Value: 8628.62, Comm: 4.06
# 2019-10-09 BUY ORDER PLACED
# 2019-10-10 BUY ORDER EXECUTED for BTCUSDT: Price: 8562.15, Value: 8166.60, Comm 4.08
# 2020-02-19 SELL ORDER EXECUTED for BTCUSDT: Price: 10164.78, Value: 8166.60, Comm: 4.85
# 2020-02-23 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 10592.168881051784
#
# Finished backtest 2 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ======================================
# Starting backtest 3/162 with 1 run(s)
#
# ======================================
# Adding strategy datafeeds
# 2019-01-02 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2019-07-21 BACKTEST STARTING
# 2019-08-02 BUY ORDER PLACED
# 2019-08-03 BUY ORDER EXECUTED for BTCUSDT: Price: 10523.75, Value: 9000.00, Comm 4.50
# 2019-08-15 SELL ORDER EXECUTED for BTCUSDT: Price: 10055.16, Value: 9000.00, Comm: 4.30
# 2019-09-03 BUY ORDER PLACED
# 2019-09-04 BUY ORDER EXECUTED for BTCUSDT: Price: 10611.85, Value: 8628.62, Comm 4.31
# 2019-09-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9985.15, Value: 8628.62, Comm: 4.06
# 2019-10-09 BUY ORDER PLACED
# 2019-10-10 BUY ORDER EXECUTED for BTCUSDT: Price: 8562.15, Value: 8166.60, Comm 4.08
# 2020-02-19 SELL ORDER EXECUTED for BTCUSDT: Price: 10164.78, Value: 8166.60, Comm: 4.85
# 2020-02-23 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 10592.168881051784
#
# Finished backtest 3 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ======================================
# Starting backtest 4/162 with 1 run(s)
#
# ======================================
# Adding strategy datafeeds
# 2019-01-02 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2019-07-21 BACKTEST STARTING
# 2019-08-02 BUY ORDER PLACED
# 2019-08-03 BUY ORDER EXECUTED for BTCUSDT: Price: 10523.75, Value: 9000.00, Comm 4.50
# 2019-08-15 SELL ORDER EXECUTED for BTCUSDT: Price: 10055.16, Value: 9000.00, Comm: 4.30
# 2019-09-03 BUY ORDER PLACED
# 2019-09-04 BUY ORDER EXECUTED for BTCUSDT: Price: 10611.85, Value: 8628.62, Comm 4.31
# 2019-09-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9985.15, Value: 8628.62, Comm: 4.06
# 2019-10-09 BUY ORDER PLACED
# 2019-10-10 BUY ORDER EXECUTED for BTCUSDT: Price: 8562.15, Value: 8166.60, Comm 4.08
# 2020-02-19 SELL ORDER EXECUTED for BTCUSDT: Price: 10164.78, Value: 8166.60, Comm: 4.85
# 2020-02-23 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 10592.168881051784
#
# Finished backtest 4 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ======================================
# Starting backtest 5/162 with 1 run(s)
#
# ======================================
# Adding strategy datafeeds
# 2019-01-02 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2019-07-21 BACKTEST STARTING
# 2019-08-02 BUY ORDER PLACED
# 2019-08-03 BUY ORDER EXECUTED for BTCUSDT: Price: 10523.75, Value: 9000.00, Comm 4.50
# 2019-08-15 SELL ORDER EXECUTED for BTCUSDT: Price: 10055.16, Value: 9000.00, Comm: 4.30
# 2019-09-03 BUY ORDER PLACED
# 2019-09-04 BUY ORDER EXECUTED for BTCUSDT: Price: 10611.85, Value: 8628.62, Comm 4.31
# 2019-09-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9985.15, Value: 8628.62, Comm: 4.06
# 2019-10-09 BUY ORDER PLACED
# 2019-10-10 BUY ORDER EXECUTED for BTCUSDT: Price: 8562.15, Value: 8166.60, Comm 4.08
# 2020-02-19 SELL ORDER EXECUTED for BTCUSDT: Price: 10164.78, Value: 8166.60, Comm: 4.85
# 2020-02-23 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 10592.168881051784
#
# Finished backtest 5 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ======================================
# Starting backtest 6/162 with 1 run(s)
#
# ======================================
# Adding strategy datafeeds
# 2019-01-02 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2019-07-21 BACKTEST STARTING
# 2019-08-02 BUY ORDER PLACED
# 2019-08-03 BUY ORDER EXECUTED for BTCUSDT: Price: 10523.75, Value: 9000.00, Comm 4.50
# 2019-08-15 SELL ORDER EXECUTED for BTCUSDT: Price: 10055.16, Value: 9000.00, Comm: 4.30
# 2019-09-03 BUY ORDER PLACED
# 2019-09-04 BUY ORDER EXECUTED for BTCUSDT: Price: 10611.85, Value: 8628.62, Comm 4.31
# 2019-09-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9985.15, Value: 8628.62, Comm: 4.06
# 2019-10-09 BUY ORDER PLACED
# 2019-10-10 BUY ORDER EXECUTED for BTCUSDT: Price: 8562.15, Value: 8166.60, Comm 4.08
# 2020-02-19 SELL ORDER EXECUTED for BTCUSDT: Price: 10164.78, Value: 8166.60, Comm: 4.85
# 2020-02-23 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 10592.168881051784
#
# Finished backtest 6 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ======================================
# Starting backtest 7/162 with 1 run(s)
#
# ======================================
# Adding strategy datafeeds
# 2019-01-02 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2019-07-21 BACKTEST STARTING
# 2019-08-02 BUY ORDER PLACED
# 2019-08-03 BUY ORDER EXECUTED for BTCUSDT: Price: 10523.75, Value: 9000.00, Comm 4.50
# 2019-08-15 SELL ORDER EXECUTED for BTCUSDT: Price: 10055.16, Value: 9000.00, Comm: 4.30
# 2019-09-03 BUY ORDER PLACED
# 2019-09-04 BUY ORDER EXECUTED for BTCUSDT: Price: 10611.85, Value: 8628.62, Comm 4.31
# 2019-09-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9985.15, Value: 8628.62, Comm: 4.06
# 2019-10-09 BUY ORDER PLACED
# 2019-10-10 BUY ORDER EXECUTED for BTCUSDT: Price: 8562.15, Value: 8166.60, Comm 4.08
# 2020-02-19 SELL ORDER EXECUTED for BTCUSDT: Price: 10164.78, Value: 8166.60, Comm: 4.85
# 2020-02-23 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 10592.168881051784
#
# Finished backtest 7 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ======================================
# Starting backtest 8/162 with 1 run(s)
#
# ======================================
# Adding strategy datafeeds
# 2019-01-02 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2019-07-21 BACKTEST STARTING
# 2019-08-02 BUY ORDER PLACED
# 2019-08-03 BUY ORDER EXECUTED for BTCUSDT: Price: 10523.75, Value: 9000.00, Comm 4.50
# 2019-08-15 SELL ORDER EXECUTED for BTCUSDT: Price: 10055.16, Value: 9000.00, Comm: 4.30
# 2019-09-03 BUY ORDER PLACED
# 2019-09-04 BUY ORDER EXECUTED for BTCUSDT: Price: 10611.85, Value: 8628.62, Comm 4.31
# 2019-09-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9985.15, Value: 8628.62, Comm: 4.06
# 2019-10-09 BUY ORDER PLACED
# 2019-10-10 BUY ORDER EXECUTED for BTCUSDT: Price: 8562.15, Value: 8166.60, Comm 4.08
# 2020-02-19 SELL ORDER EXECUTED for BTCUSDT: Price: 10164.78, Value: 8166.60, Comm: 4.85
# 2020-02-23 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 10592.168881051784
#
# Finished backtest 8 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ======================================
# Starting backtest 9/162 with 1 run(s)
#
# ======================================
# Adding strategy datafeeds
# 2019-01-02 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2019-07-21 BACKTEST STARTING
# 2019-08-02 BUY ORDER PLACED
# 2019-08-03 BUY ORDER EXECUTED for BTCUSDT: Price: 10523.75, Value: 9000.00, Comm 4.50
# 2019-08-15 SELL ORDER EXECUTED for BTCUSDT: Price: 10055.16, Value: 9000.00, Comm: 4.30
# 2019-09-03 BUY ORDER PLACED
# 2019-09-04 BUY ORDER EXECUTED for BTCUSDT: Price: 10611.85, Value: 8628.62, Comm 4.31
# 2019-09-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9985.15, Value: 8628.62, Comm: 4.06
# 2019-10-09 BUY ORDER PLACED
# 2019-10-10 BUY ORDER EXECUTED for BTCUSDT: Price: 8562.15, Value: 8166.60, Comm 4.08
# 2020-02-19 SELL ORDER EXECUTED for BTCUSDT: Price: 10164.78, Value: 8166.60, Comm: 4.85
# 2020-02-23 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 10592.168881051784
#
# Finished backtest 9 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 10/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2019-08-07 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-02-23 BACKTEST STARTING
# 2020-03-23 BUY ORDER PLACED
# 2020-03-24 BUY ORDER EXECUTED for BTCUSDT: Price: 6465.25, Value: 8997.13, Comm 4.50
# 2020-05-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9067.51, Value: 8997.13, Comm: 6.31
# 2020-07-08 BUY ORDER PLACED
# 2020-07-09 BUY ORDER EXECUTED for BTCUSDT: Price: 9436.06, Value: 12249.48, Comm 6.12
# 2020-08-13 SELL ORDER EXECUTED for BTCUSDT: Price: 11564.34, Value: 12249.48, Comm: 7.51
# 2020-09-16 BUY ORDER PLACED
# 2020-09-17 BUY ORDER EXECUTED for BTCUSDT: Price: 10954.01, Value: 14723.77, Comm 7.36
# 2020-09-27 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 16110.757904089322
#
# Finished backtest 10 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 11/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2019-08-07 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-02-23 BACKTEST STARTING
# 2020-03-23 BUY ORDER PLACED
# 2020-03-24 BUY ORDER EXECUTED for BTCUSDT: Price: 6465.25, Value: 8997.13, Comm 4.50
# 2020-05-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9067.51, Value: 8997.13, Comm: 6.31
# 2020-07-08 BUY ORDER PLACED
# 2020-07-09 BUY ORDER EXECUTED for BTCUSDT: Price: 9436.06, Value: 12249.48, Comm 6.12
# 2020-08-13 SELL ORDER EXECUTED for BTCUSDT: Price: 11564.34, Value: 12249.48, Comm: 7.51
# 2020-09-16 BUY ORDER PLACED
# 2020-09-17 BUY ORDER EXECUTED for BTCUSDT: Price: 10954.01, Value: 14723.77, Comm 7.36
# 2020-09-27 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 16110.757904089322
#
# Finished backtest 11 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 12/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2019-08-07 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-02-23 BACKTEST STARTING
# 2020-03-23 BUY ORDER PLACED
# 2020-03-24 BUY ORDER EXECUTED for BTCUSDT: Price: 6465.25, Value: 8997.13, Comm 4.50
# 2020-05-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9067.51, Value: 8997.13, Comm: 6.31
# 2020-07-08 BUY ORDER PLACED
# 2020-07-09 BUY ORDER EXECUTED for BTCUSDT: Price: 9436.06, Value: 12249.48, Comm 6.12
# 2020-08-13 SELL ORDER EXECUTED for BTCUSDT: Price: 11564.34, Value: 12249.48, Comm: 7.51
# 2020-09-16 BUY ORDER PLACED
# 2020-09-17 BUY ORDER EXECUTED for BTCUSDT: Price: 10954.01, Value: 14723.77, Comm 7.36
# 2020-09-27 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 16110.757904089322
#
# Finished backtest 12 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 13/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2019-08-07 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-02-23 BACKTEST STARTING
# 2020-03-23 BUY ORDER PLACED
# 2020-03-24 BUY ORDER EXECUTED for BTCUSDT: Price: 6465.25, Value: 8997.13, Comm 4.50
# 2020-05-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9067.51, Value: 8997.13, Comm: 6.31
# 2020-07-08 BUY ORDER PLACED
# 2020-07-09 BUY ORDER EXECUTED for BTCUSDT: Price: 9436.06, Value: 12249.48, Comm 6.12
# 2020-08-13 SELL ORDER EXECUTED for BTCUSDT: Price: 11564.34, Value: 12249.48, Comm: 7.51
# 2020-09-16 BUY ORDER PLACED
# 2020-09-17 BUY ORDER EXECUTED for BTCUSDT: Price: 10954.01, Value: 14723.77, Comm 7.36
# 2020-09-27 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 16110.757904089322
#
# Finished backtest 13 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 14/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2019-08-07 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-02-23 BACKTEST STARTING
# 2020-03-23 BUY ORDER PLACED
# 2020-03-24 BUY ORDER EXECUTED for BTCUSDT: Price: 6465.25, Value: 8997.13, Comm 4.50
# 2020-05-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9067.51, Value: 8997.13, Comm: 6.31
# 2020-07-08 BUY ORDER PLACED
# 2020-07-09 BUY ORDER EXECUTED for BTCUSDT: Price: 9436.06, Value: 12249.48, Comm 6.12
# 2020-08-13 SELL ORDER EXECUTED for BTCUSDT: Price: 11564.34, Value: 12249.48, Comm: 7.51
# 2020-09-16 BUY ORDER PLACED
# 2020-09-17 BUY ORDER EXECUTED for BTCUSDT: Price: 10954.01, Value: 14723.77, Comm 7.36
# 2020-09-27 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 16110.757904089322
#
# Finished backtest 14 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 15/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2019-08-07 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-02-23 BACKTEST STARTING
# 2020-03-23 BUY ORDER PLACED
# 2020-03-24 BUY ORDER EXECUTED for BTCUSDT: Price: 6465.25, Value: 8997.13, Comm 4.50
# 2020-05-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9067.51, Value: 8997.13, Comm: 6.31
# 2020-07-08 BUY ORDER PLACED
# 2020-07-09 BUY ORDER EXECUTED for BTCUSDT: Price: 9436.06, Value: 12249.48, Comm 6.12
# 2020-08-13 SELL ORDER EXECUTED for BTCUSDT: Price: 11564.34, Value: 12249.48, Comm: 7.51
# 2020-09-16 BUY ORDER PLACED
# 2020-09-17 BUY ORDER EXECUTED for BTCUSDT: Price: 10954.01, Value: 14723.77, Comm 7.36
# 2020-09-27 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 16110.757904089322
#
# Finished backtest 15 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 16/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2019-08-07 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-02-23 BACKTEST STARTING
# 2020-03-23 BUY ORDER PLACED
# 2020-03-24 BUY ORDER EXECUTED for BTCUSDT: Price: 6465.25, Value: 8997.13, Comm 4.50
# 2020-05-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9067.51, Value: 8997.13, Comm: 6.31
# 2020-07-08 BUY ORDER PLACED
# 2020-07-09 BUY ORDER EXECUTED for BTCUSDT: Price: 9436.06, Value: 12249.48, Comm 6.12
# 2020-08-13 SELL ORDER EXECUTED for BTCUSDT: Price: 11564.34, Value: 12249.48, Comm: 7.51
# 2020-09-16 BUY ORDER PLACED
# 2020-09-17 BUY ORDER EXECUTED for BTCUSDT: Price: 10954.01, Value: 14723.77, Comm 7.36
# 2020-09-27 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 16110.757904089322
#
# Finished backtest 16 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 17/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2019-08-07 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-02-23 BACKTEST STARTING
# 2020-03-23 BUY ORDER PLACED
# 2020-03-24 BUY ORDER EXECUTED for BTCUSDT: Price: 6465.25, Value: 8997.13, Comm 4.50
# 2020-05-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9067.51, Value: 8997.13, Comm: 6.31
# 2020-07-08 BUY ORDER PLACED
# 2020-07-09 BUY ORDER EXECUTED for BTCUSDT: Price: 9436.06, Value: 12249.48, Comm 6.12
# 2020-08-13 SELL ORDER EXECUTED for BTCUSDT: Price: 11564.34, Value: 12249.48, Comm: 7.51
# 2020-09-16 BUY ORDER PLACED
# 2020-09-17 BUY ORDER EXECUTED for BTCUSDT: Price: 10954.01, Value: 14723.77, Comm 7.36
# 2020-09-27 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 16110.757904089322
#
# Finished backtest 17 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 18/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2019-08-07 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-02-23 BACKTEST STARTING
# 2020-03-23 BUY ORDER PLACED
# 2020-03-24 BUY ORDER EXECUTED for BTCUSDT: Price: 6465.25, Value: 8997.13, Comm 4.50
# 2020-05-22 SELL ORDER EXECUTED for BTCUSDT: Price: 9067.51, Value: 8997.13, Comm: 6.31
# 2020-07-08 BUY ORDER PLACED
# 2020-07-09 BUY ORDER EXECUTED for BTCUSDT: Price: 9436.06, Value: 12249.48, Comm 6.12
# 2020-08-13 SELL ORDER EXECUTED for BTCUSDT: Price: 11564.34, Value: 12249.48, Comm: 7.51
# 2020-09-16 BUY ORDER PLACED
# 2020-09-17 BUY ORDER EXECUTED for BTCUSDT: Price: 10954.01, Value: 14723.77, Comm 7.36
# 2020-09-27 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 16110.757904089322
#
# Finished backtest 18 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 19/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-03-11 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-09-27 BACKTEST STARTING
# 2020-09-27 BUY ORDER PLACED
# 2020-09-28 BUY ORDER EXECUTED for BTCUSDT: Price: 10774.26, Value: 9000.01, Comm 4.50
# 2020-11-27 SELL ORDER EXECUTED for BTCUSDT: Price: 17149.47, Value: 9000.01, Comm: 7.16
# 2020-12-16 BUY ORDER PLACED
# 2020-12-17 BUY ORDER EXECUTED for BTCUSDT: Price: 21335.52, Value: 13782.34, Comm 6.89
# 2021-01-16 SELL ORDER EXECUTED for BTCUSDT: Price: 36737.43, Value: 13782.34, Comm: 11.87
# 2021-02-04 BUY ORDER PLACED
# 2021-02-05 BUY ORDER EXECUTED for BTCUSDT: Price: 36936.65, Value: 22719.86, Comm 11.36
# 2021-02-25 SELL ORDER EXECUTED for BTCUSDT: Price: 49676.21, Value: 22719.86, Comm: 15.28
# 2021-03-10 BUY ORDER PLACED
# 2021-03-11 BUY ORDER EXECUTED for BTCUSDT: Price: 55851.59, Value: 29748.42, Comm 14.87
# 2021-03-22 SELL ORDER EXECUTED for BTCUSDT: Price: 57351.56, Value: 29748.42, Comm: 15.27
# 2021-04-02 BUY ORDER PLACED
# 2021-04-03 BUY ORDER EXECUTED for BTCUSDT: Price: 58950.01, Value: 30440.33, Comm 15.22
# 2021-04-04 SELL ORDER EXECUTED for BTCUSDT: Price: 57051.95, Value: 30440.33, Comm: 14.73
# 2021-04-12 BUY ORDER PLACED
# 2021-04-13 BUY ORDER EXECUTED for BTCUSDT: Price: 59860.01, Value: 29531.28, Comm 14.77
# 2021-04-19 SELL ORDER EXECUTED for BTCUSDT: Price: 56150.01, Value: 29531.28, Comm: 13.85
# 2021-05-01 BUY ORDER PLACED
# 2021-05-02 BUY ORDER EXECUTED for BTCUSDT: Price: 57797.35, Value: 27856.80, Comm 13.93
# 2021-05-02 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 30352.09903252433
#
# Finished backtest 19 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 20/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-03-11 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-09-27 BACKTEST STARTING
# 2020-09-27 BUY ORDER PLACED
# 2020-09-28 BUY ORDER EXECUTED for BTCUSDT: Price: 10774.26, Value: 9000.01, Comm 4.50
# 2020-11-27 SELL ORDER EXECUTED for BTCUSDT: Price: 17149.47, Value: 9000.01, Comm: 7.16
# 2020-12-16 BUY ORDER PLACED
# 2020-12-17 BUY ORDER EXECUTED for BTCUSDT: Price: 21335.52, Value: 13782.34, Comm 6.89
# 2021-01-16 SELL ORDER EXECUTED for BTCUSDT: Price: 36737.43, Value: 13782.34, Comm: 11.87
# 2021-02-04 BUY ORDER PLACED
# 2021-02-05 BUY ORDER EXECUTED for BTCUSDT: Price: 36936.65, Value: 22719.86, Comm 11.36
# 2021-02-25 SELL ORDER EXECUTED for BTCUSDT: Price: 49676.21, Value: 22719.86, Comm: 15.28
# 2021-03-10 BUY ORDER PLACED
# 2021-03-11 BUY ORDER EXECUTED for BTCUSDT: Price: 55851.59, Value: 29748.42, Comm 14.87
# 2021-03-22 SELL ORDER EXECUTED for BTCUSDT: Price: 57351.56, Value: 29748.42, Comm: 15.27
# 2021-04-02 BUY ORDER PLACED
# 2021-04-03 BUY ORDER EXECUTED for BTCUSDT: Price: 58950.01, Value: 30440.33, Comm 15.22
# 2021-04-04 SELL ORDER EXECUTED for BTCUSDT: Price: 57051.95, Value: 30440.33, Comm: 14.73
# 2021-04-12 BUY ORDER PLACED
# 2021-04-13 BUY ORDER EXECUTED for BTCUSDT: Price: 59860.01, Value: 29531.28, Comm 14.77
# 2021-04-19 SELL ORDER EXECUTED for BTCUSDT: Price: 56150.01, Value: 29531.28, Comm: 13.85
# 2021-05-01 BUY ORDER PLACED
# 2021-05-02 BUY ORDER EXECUTED for BTCUSDT: Price: 57797.35, Value: 27856.80, Comm 13.93
# 2021-05-02 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 30352.09903252433
#
# Finished backtest 20 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 21/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-03-11 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-09-27 BACKTEST STARTING
# 2020-09-27 BUY ORDER PLACED
# 2020-09-28 BUY ORDER EXECUTED for BTCUSDT: Price: 10774.26, Value: 9000.01, Comm 4.50
# 2020-11-27 SELL ORDER EXECUTED for BTCUSDT: Price: 17149.47, Value: 9000.01, Comm: 7.16
# 2020-12-16 BUY ORDER PLACED
# 2020-12-17 BUY ORDER EXECUTED for BTCUSDT: Price: 21335.52, Value: 13782.34, Comm 6.89
# 2021-01-16 SELL ORDER EXECUTED for BTCUSDT: Price: 36737.43, Value: 13782.34, Comm: 11.87
# 2021-02-04 BUY ORDER PLACED
# 2021-02-05 BUY ORDER EXECUTED for BTCUSDT: Price: 36936.65, Value: 22719.86, Comm 11.36
# 2021-02-25 SELL ORDER EXECUTED for BTCUSDT: Price: 49676.21, Value: 22719.86, Comm: 15.28
# 2021-03-10 BUY ORDER PLACED
# 2021-03-11 BUY ORDER EXECUTED for BTCUSDT: Price: 55851.59, Value: 29748.42, Comm 14.87
# 2021-03-22 SELL ORDER EXECUTED for BTCUSDT: Price: 57351.56, Value: 29748.42, Comm: 15.27
# 2021-04-02 BUY ORDER PLACED
# 2021-04-03 BUY ORDER EXECUTED for BTCUSDT: Price: 58950.01, Value: 30440.33, Comm 15.22
# 2021-04-04 SELL ORDER EXECUTED for BTCUSDT: Price: 57051.95, Value: 30440.33, Comm: 14.73
# 2021-04-12 BUY ORDER PLACED
# 2021-04-13 BUY ORDER EXECUTED for BTCUSDT: Price: 59860.01, Value: 29531.28, Comm 14.77
# 2021-04-19 SELL ORDER EXECUTED for BTCUSDT: Price: 56150.01, Value: 29531.28, Comm: 13.85
# 2021-05-01 BUY ORDER PLACED
# 2021-05-02 BUY ORDER EXECUTED for BTCUSDT: Price: 57797.35, Value: 27856.80, Comm 13.93
# 2021-05-02 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 30352.09903252433
#
# Finished backtest 21 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 22/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-03-11 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-09-27 BACKTEST STARTING
# 2020-09-27 BUY ORDER PLACED
# 2020-09-28 BUY ORDER EXECUTED for BTCUSDT: Price: 10774.26, Value: 9000.01, Comm 4.50
# 2020-11-27 SELL ORDER EXECUTED for BTCUSDT: Price: 17149.47, Value: 9000.01, Comm: 7.16
# 2020-12-16 BUY ORDER PLACED
# 2020-12-17 BUY ORDER EXECUTED for BTCUSDT: Price: 21335.52, Value: 13782.34, Comm 6.89
# 2021-01-16 SELL ORDER EXECUTED for BTCUSDT: Price: 36737.43, Value: 13782.34, Comm: 11.87
# 2021-02-04 BUY ORDER PLACED
# 2021-02-05 BUY ORDER EXECUTED for BTCUSDT: Price: 36936.65, Value: 22719.86, Comm 11.36
# 2021-02-25 SELL ORDER EXECUTED for BTCUSDT: Price: 49676.21, Value: 22719.86, Comm: 15.28
# 2021-03-10 BUY ORDER PLACED
# 2021-03-11 BUY ORDER EXECUTED for BTCUSDT: Price: 55851.59, Value: 29748.42, Comm 14.87
# 2021-03-22 SELL ORDER EXECUTED for BTCUSDT: Price: 57351.56, Value: 29748.42, Comm: 15.27
# 2021-04-02 BUY ORDER PLACED
# 2021-04-03 BUY ORDER EXECUTED for BTCUSDT: Price: 58950.01, Value: 30440.33, Comm 15.22
# 2021-04-04 SELL ORDER EXECUTED for BTCUSDT: Price: 57051.95, Value: 30440.33, Comm: 14.73
# 2021-04-12 BUY ORDER PLACED
# 2021-04-13 BUY ORDER EXECUTED for BTCUSDT: Price: 59860.01, Value: 29531.28, Comm 14.77
# 2021-04-19 SELL ORDER EXECUTED for BTCUSDT: Price: 56150.01, Value: 29531.28, Comm: 13.85
# 2021-05-01 BUY ORDER PLACED
# 2021-05-02 BUY ORDER EXECUTED for BTCUSDT: Price: 57797.35, Value: 27856.80, Comm 13.93
# 2021-05-02 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 30352.09903252433
#
# Finished backtest 22 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 23/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-03-11 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-09-27 BACKTEST STARTING
# 2020-09-27 BUY ORDER PLACED
# 2020-09-28 BUY ORDER EXECUTED for BTCUSDT: Price: 10774.26, Value: 9000.01, Comm 4.50
# 2020-11-27 SELL ORDER EXECUTED for BTCUSDT: Price: 17149.47, Value: 9000.01, Comm: 7.16
# 2020-12-16 BUY ORDER PLACED
# 2020-12-17 BUY ORDER EXECUTED for BTCUSDT: Price: 21335.52, Value: 13782.34, Comm 6.89
# 2021-01-16 SELL ORDER EXECUTED for BTCUSDT: Price: 36737.43, Value: 13782.34, Comm: 11.87
# 2021-02-04 BUY ORDER PLACED
# 2021-02-05 BUY ORDER EXECUTED for BTCUSDT: Price: 36936.65, Value: 22719.86, Comm 11.36
# 2021-02-25 SELL ORDER EXECUTED for BTCUSDT: Price: 49676.21, Value: 22719.86, Comm: 15.28
# 2021-03-10 BUY ORDER PLACED
# 2021-03-11 BUY ORDER EXECUTED for BTCUSDT: Price: 55851.59, Value: 29748.42, Comm 14.87
# 2021-03-22 SELL ORDER EXECUTED for BTCUSDT: Price: 57351.56, Value: 29748.42, Comm: 15.27
# 2021-04-02 BUY ORDER PLACED
# 2021-04-03 BUY ORDER EXECUTED for BTCUSDT: Price: 58950.01, Value: 30440.33, Comm 15.22
# 2021-04-04 SELL ORDER EXECUTED for BTCUSDT: Price: 57051.95, Value: 30440.33, Comm: 14.73
# 2021-04-12 BUY ORDER PLACED
# 2021-04-13 BUY ORDER EXECUTED for BTCUSDT: Price: 59860.01, Value: 29531.28, Comm 14.77
# 2021-04-19 SELL ORDER EXECUTED for BTCUSDT: Price: 56150.01, Value: 29531.28, Comm: 13.85
# 2021-05-01 BUY ORDER PLACED
# 2021-05-02 BUY ORDER EXECUTED for BTCUSDT: Price: 57797.35, Value: 27856.80, Comm 13.93
# 2021-05-02 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 30352.09903252433
#
# Finished backtest 23 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 24/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-03-11 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-09-27 BACKTEST STARTING
# 2020-09-27 BUY ORDER PLACED
# 2020-09-28 BUY ORDER EXECUTED for BTCUSDT: Price: 10774.26, Value: 9000.01, Comm 4.50
# 2020-11-27 SELL ORDER EXECUTED for BTCUSDT: Price: 17149.47, Value: 9000.01, Comm: 7.16
# 2020-12-16 BUY ORDER PLACED
# 2020-12-17 BUY ORDER EXECUTED for BTCUSDT: Price: 21335.52, Value: 13782.34, Comm 6.89
# 2021-01-16 SELL ORDER EXECUTED for BTCUSDT: Price: 36737.43, Value: 13782.34, Comm: 11.87
# 2021-02-04 BUY ORDER PLACED
# 2021-02-05 BUY ORDER EXECUTED for BTCUSDT: Price: 36936.65, Value: 22719.86, Comm 11.36
# 2021-02-25 SELL ORDER EXECUTED for BTCUSDT: Price: 49676.21, Value: 22719.86, Comm: 15.28
# 2021-03-10 BUY ORDER PLACED
# 2021-03-11 BUY ORDER EXECUTED for BTCUSDT: Price: 55851.59, Value: 29748.42, Comm 14.87
# 2021-03-22 SELL ORDER EXECUTED for BTCUSDT: Price: 57351.56, Value: 29748.42, Comm: 15.27
# 2021-04-02 BUY ORDER PLACED
# 2021-04-03 BUY ORDER EXECUTED for BTCUSDT: Price: 58950.01, Value: 30440.33, Comm 15.22
# 2021-04-04 SELL ORDER EXECUTED for BTCUSDT: Price: 57051.95, Value: 30440.33, Comm: 14.73
# 2021-04-12 BUY ORDER PLACED
# 2021-04-13 BUY ORDER EXECUTED for BTCUSDT: Price: 59860.01, Value: 29531.28, Comm 14.77
# 2021-04-19 SELL ORDER EXECUTED for BTCUSDT: Price: 56150.01, Value: 29531.28, Comm: 13.85
# 2021-05-01 BUY ORDER PLACED
# 2021-05-02 BUY ORDER EXECUTED for BTCUSDT: Price: 57797.35, Value: 27856.80, Comm 13.93
# 2021-05-02 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 30352.09903252433
#
# Finished backtest 24 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 25/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-03-11 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-09-27 BACKTEST STARTING
# 2020-09-27 BUY ORDER PLACED
# 2020-09-28 BUY ORDER EXECUTED for BTCUSDT: Price: 10774.26, Value: 9000.01, Comm 4.50
# 2020-11-27 SELL ORDER EXECUTED for BTCUSDT: Price: 17149.47, Value: 9000.01, Comm: 7.16
# 2020-12-16 BUY ORDER PLACED
# 2020-12-17 BUY ORDER EXECUTED for BTCUSDT: Price: 21335.52, Value: 13782.34, Comm 6.89
# 2021-01-16 SELL ORDER EXECUTED for BTCUSDT: Price: 36737.43, Value: 13782.34, Comm: 11.87
# 2021-02-04 BUY ORDER PLACED
# 2021-02-05 BUY ORDER EXECUTED for BTCUSDT: Price: 36936.65, Value: 22719.86, Comm 11.36
# 2021-02-25 SELL ORDER EXECUTED for BTCUSDT: Price: 49676.21, Value: 22719.86, Comm: 15.28
# 2021-03-10 BUY ORDER PLACED
# 2021-03-11 BUY ORDER EXECUTED for BTCUSDT: Price: 55851.59, Value: 29748.42, Comm 14.87
# 2021-03-22 SELL ORDER EXECUTED for BTCUSDT: Price: 57351.56, Value: 29748.42, Comm: 15.27
# 2021-04-02 BUY ORDER PLACED
# 2021-04-03 BUY ORDER EXECUTED for BTCUSDT: Price: 58950.01, Value: 30440.33, Comm 15.22
# 2021-04-04 SELL ORDER EXECUTED for BTCUSDT: Price: 57051.95, Value: 30440.33, Comm: 14.73
# 2021-04-12 BUY ORDER PLACED
# 2021-04-13 BUY ORDER EXECUTED for BTCUSDT: Price: 59860.01, Value: 29531.28, Comm 14.77
# 2021-04-19 SELL ORDER EXECUTED for BTCUSDT: Price: 56150.01, Value: 29531.28, Comm: 13.85
# 2021-05-01 BUY ORDER PLACED
# 2021-05-02 BUY ORDER EXECUTED for BTCUSDT: Price: 57797.35, Value: 27856.80, Comm 13.93
# 2021-05-02 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 30352.09903252433
#
# Finished backtest 25 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 26/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-03-11 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-09-27 BACKTEST STARTING
# 2020-09-27 BUY ORDER PLACED
# 2020-09-28 BUY ORDER EXECUTED for BTCUSDT: Price: 10774.26, Value: 9000.01, Comm 4.50
# 2020-11-27 SELL ORDER EXECUTED for BTCUSDT: Price: 17149.47, Value: 9000.01, Comm: 7.16
# 2020-12-16 BUY ORDER PLACED
# 2020-12-17 BUY ORDER EXECUTED for BTCUSDT: Price: 21335.52, Value: 13782.34, Comm 6.89
# 2021-01-16 SELL ORDER EXECUTED for BTCUSDT: Price: 36737.43, Value: 13782.34, Comm: 11.87
# 2021-02-04 BUY ORDER PLACED
# 2021-02-05 BUY ORDER EXECUTED for BTCUSDT: Price: 36936.65, Value: 22719.86, Comm 11.36
# 2021-02-25 SELL ORDER EXECUTED for BTCUSDT: Price: 49676.21, Value: 22719.86, Comm: 15.28
# 2021-03-10 BUY ORDER PLACED
# 2021-03-11 BUY ORDER EXECUTED for BTCUSDT: Price: 55851.59, Value: 29748.42, Comm 14.87
# 2021-03-22 SELL ORDER EXECUTED for BTCUSDT: Price: 57351.56, Value: 29748.42, Comm: 15.27
# 2021-04-02 BUY ORDER PLACED
# 2021-04-03 BUY ORDER EXECUTED for BTCUSDT: Price: 58950.01, Value: 30440.33, Comm 15.22
# 2021-04-04 SELL ORDER EXECUTED for BTCUSDT: Price: 57051.95, Value: 30440.33, Comm: 14.73
# 2021-04-12 BUY ORDER PLACED
# 2021-04-13 BUY ORDER EXECUTED for BTCUSDT: Price: 59860.01, Value: 29531.28, Comm 14.77
# 2021-04-19 SELL ORDER EXECUTED for BTCUSDT: Price: 56150.01, Value: 29531.28, Comm: 13.85
# 2021-05-01 BUY ORDER PLACED
# 2021-05-02 BUY ORDER EXECUTED for BTCUSDT: Price: 57797.35, Value: 27856.80, Comm 13.93
# 2021-05-02 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 30352.09903252433
#
# Finished backtest 26 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 27/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-03-11 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2020-09-27 BACKTEST STARTING
# 2020-09-27 BUY ORDER PLACED
# 2020-09-28 BUY ORDER EXECUTED for BTCUSDT: Price: 10774.26, Value: 9000.01, Comm 4.50
# 2020-11-27 SELL ORDER EXECUTED for BTCUSDT: Price: 17149.47, Value: 9000.01, Comm: 7.16
# 2020-12-16 BUY ORDER PLACED
# 2020-12-17 BUY ORDER EXECUTED for BTCUSDT: Price: 21335.52, Value: 13782.34, Comm 6.89
# 2021-01-16 SELL ORDER EXECUTED for BTCUSDT: Price: 36737.43, Value: 13782.34, Comm: 11.87
# 2021-02-04 BUY ORDER PLACED
# 2021-02-05 BUY ORDER EXECUTED for BTCUSDT: Price: 36936.65, Value: 22719.86, Comm 11.36
# 2021-02-25 SELL ORDER EXECUTED for BTCUSDT: Price: 49676.21, Value: 22719.86, Comm: 15.28
# 2021-03-10 BUY ORDER PLACED
# 2021-03-11 BUY ORDER EXECUTED for BTCUSDT: Price: 55851.59, Value: 29748.42, Comm 14.87
# 2021-03-22 SELL ORDER EXECUTED for BTCUSDT: Price: 57351.56, Value: 29748.42, Comm: 15.27
# 2021-04-02 BUY ORDER PLACED
# 2021-04-03 BUY ORDER EXECUTED for BTCUSDT: Price: 58950.01, Value: 30440.33, Comm 15.22
# 2021-04-04 SELL ORDER EXECUTED for BTCUSDT: Price: 57051.95, Value: 30440.33, Comm: 14.73
# 2021-04-12 BUY ORDER PLACED
# 2021-04-13 BUY ORDER EXECUTED for BTCUSDT: Price: 59860.01, Value: 29531.28, Comm 14.77
# 2021-04-19 SELL ORDER EXECUTED for BTCUSDT: Price: 56150.01, Value: 29531.28, Comm: 13.85
# 2021-05-01 BUY ORDER PLACED
# 2021-05-02 BUY ORDER EXECUTED for BTCUSDT: Price: 57797.35, Value: 27856.80, Comm 13.93
# 2021-05-02 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 30352.09903252433
#
# Finished backtest 27 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 28/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-10-14 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2021-05-02 BACKTEST STARTING
# 2021-05-02 BUY ORDER PLACED
# 2021-05-03 BUY ORDER EXECUTED for BTCUSDT: Price: 56578.21, Value: 9000.00, Comm 4.50
# 2021-05-13 SELL ORDER EXECUTED for BTCUSDT: Price: 49537.15, Value: 9000.00, Comm: 3.94
# 2021-06-01 BUY ORDER PLACED
# 2021-06-02 BUY ORDER EXECUTED for BTCUSDT: Price: 36694.85, Value: 7984.76, Comm 3.99
# 2021-09-16 SELL ORDER EXECUTED for BTCUSDT: Price: 48121.40, Value: 7984.76, Comm: 5.24
# 2021-10-01 BUY ORDER PLACED
# 2021-10-02 BUY ORDER EXECUTED for BTCUSDT: Price: 48141.60, Value: 10213.83, Comm 5.11
# 2021-10-25 SELL ORDER EXECUTED for BTCUSDT: Price: 60852.22, Value: 10213.83, Comm: 6.46
# 2021-11-09 BUY ORDER PLACED
# 2021-11-10 BUY ORDER EXECUTED for BTCUSDT: Price: 66947.67, Value: 12630.47, Comm 6.32
# 2021-11-11 SELL ORDER EXECUTED for BTCUSDT: Price: 64882.42, Value: 12630.47, Comm: 6.12
# 2021-12-05 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 13631.783297743332
#
# Finished backtest 28 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 29/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-10-14 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2021-05-02 BACKTEST STARTING
# 2021-05-02 BUY ORDER PLACED
# 2021-05-03 BUY ORDER EXECUTED for BTCUSDT: Price: 56578.21, Value: 9000.00, Comm 4.50
# 2021-05-13 SELL ORDER EXECUTED for BTCUSDT: Price: 49537.15, Value: 9000.00, Comm: 3.94
# 2021-06-01 BUY ORDER PLACED
# 2021-06-02 BUY ORDER EXECUTED for BTCUSDT: Price: 36694.85, Value: 7984.76, Comm 3.99
# 2021-09-16 SELL ORDER EXECUTED for BTCUSDT: Price: 48121.40, Value: 7984.76, Comm: 5.24
# 2021-10-01 BUY ORDER PLACED
# 2021-10-02 BUY ORDER EXECUTED for BTCUSDT: Price: 48141.60, Value: 10213.83, Comm 5.11
# 2021-10-25 SELL ORDER EXECUTED for BTCUSDT: Price: 60852.22, Value: 10213.83, Comm: 6.46
# 2021-11-09 BUY ORDER PLACED
# 2021-11-10 BUY ORDER EXECUTED for BTCUSDT: Price: 66947.67, Value: 12630.47, Comm 6.32
# 2021-11-11 SELL ORDER EXECUTED for BTCUSDT: Price: 64882.42, Value: 12630.47, Comm: 6.12
# 2021-12-05 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 13631.783297743332
#
# Finished backtest 29 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 30/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-10-14 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2021-05-02 BACKTEST STARTING
# 2021-05-02 BUY ORDER PLACED
# 2021-05-03 BUY ORDER EXECUTED for BTCUSDT: Price: 56578.21, Value: 9000.00, Comm 4.50
# 2021-05-13 SELL ORDER EXECUTED for BTCUSDT: Price: 49537.15, Value: 9000.00, Comm: 3.94
# 2021-06-01 BUY ORDER PLACED
# 2021-06-02 BUY ORDER EXECUTED for BTCUSDT: Price: 36694.85, Value: 7984.76, Comm 3.99
# 2021-09-16 SELL ORDER EXECUTED for BTCUSDT: Price: 48121.40, Value: 7984.76, Comm: 5.24
# 2021-10-01 BUY ORDER PLACED
# 2021-10-02 BUY ORDER EXECUTED for BTCUSDT: Price: 48141.60, Value: 10213.83, Comm 5.11
# 2021-10-25 SELL ORDER EXECUTED for BTCUSDT: Price: 60852.22, Value: 10213.83, Comm: 6.46
# 2021-11-09 BUY ORDER PLACED
# 2021-11-10 BUY ORDER EXECUTED for BTCUSDT: Price: 66947.67, Value: 12630.47, Comm 6.32
# 2021-11-11 SELL ORDER EXECUTED for BTCUSDT: Price: 64882.42, Value: 12630.47, Comm: 6.12
# 2021-12-05 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 13631.783297743332
#
# Finished backtest 30 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 31/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-10-14 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2021-05-02 BACKTEST STARTING
# 2021-05-02 BUY ORDER PLACED
# 2021-05-03 BUY ORDER EXECUTED for BTCUSDT: Price: 56578.21, Value: 9000.00, Comm 4.50
# 2021-05-13 SELL ORDER EXECUTED for BTCUSDT: Price: 49537.15, Value: 9000.00, Comm: 3.94
# 2021-06-01 BUY ORDER PLACED
# 2021-06-02 BUY ORDER EXECUTED for BTCUSDT: Price: 36694.85, Value: 7984.76, Comm 3.99
# 2021-09-16 SELL ORDER EXECUTED for BTCUSDT: Price: 48121.40, Value: 7984.76, Comm: 5.24
# 2021-10-01 BUY ORDER PLACED
# 2021-10-02 BUY ORDER EXECUTED for BTCUSDT: Price: 48141.60, Value: 10213.83, Comm 5.11
# 2021-10-25 SELL ORDER EXECUTED for BTCUSDT: Price: 60852.22, Value: 10213.83, Comm: 6.46
# 2021-11-09 BUY ORDER PLACED
# 2021-11-10 BUY ORDER EXECUTED for BTCUSDT: Price: 66947.67, Value: 12630.47, Comm 6.32
# 2021-11-11 SELL ORDER EXECUTED for BTCUSDT: Price: 64882.42, Value: 12630.47, Comm: 6.12
# 2021-12-05 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 13631.783297743332
#
# Finished backtest 31 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 32/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-10-14 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2021-05-02 BACKTEST STARTING
# 2021-05-02 BUY ORDER PLACED
# 2021-05-03 BUY ORDER EXECUTED for BTCUSDT: Price: 56578.21, Value: 9000.00, Comm 4.50
# 2021-05-13 SELL ORDER EXECUTED for BTCUSDT: Price: 49537.15, Value: 9000.00, Comm: 3.94
# 2021-06-01 BUY ORDER PLACED
# 2021-06-02 BUY ORDER EXECUTED for BTCUSDT: Price: 36694.85, Value: 7984.76, Comm 3.99
# 2021-09-16 SELL ORDER EXECUTED for BTCUSDT: Price: 48121.40, Value: 7984.76, Comm: 5.24
# 2021-10-01 BUY ORDER PLACED
# 2021-10-02 BUY ORDER EXECUTED for BTCUSDT: Price: 48141.60, Value: 10213.83, Comm 5.11
# 2021-10-25 SELL ORDER EXECUTED for BTCUSDT: Price: 60852.22, Value: 10213.83, Comm: 6.46
# 2021-11-09 BUY ORDER PLACED
# 2021-11-10 BUY ORDER EXECUTED for BTCUSDT: Price: 66947.67, Value: 12630.47, Comm 6.32
# 2021-11-11 SELL ORDER EXECUTED for BTCUSDT: Price: 64882.42, Value: 12630.47, Comm: 6.12
# 2021-12-05 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 13631.783297743332
#
# Finished backtest 32 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 33/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-10-14 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2021-05-02 BACKTEST STARTING
# 2021-05-02 BUY ORDER PLACED
# 2021-05-03 BUY ORDER EXECUTED for BTCUSDT: Price: 56578.21, Value: 9000.00, Comm 4.50
# 2021-05-13 SELL ORDER EXECUTED for BTCUSDT: Price: 49537.15, Value: 9000.00, Comm: 3.94
# 2021-06-01 BUY ORDER PLACED
# 2021-06-02 BUY ORDER EXECUTED for BTCUSDT: Price: 36694.85, Value: 7984.76, Comm 3.99
# 2021-09-16 SELL ORDER EXECUTED for BTCUSDT: Price: 48121.40, Value: 7984.76, Comm: 5.24
# 2021-10-01 BUY ORDER PLACED
# 2021-10-02 BUY ORDER EXECUTED for BTCUSDT: Price: 48141.60, Value: 10213.83, Comm 5.11
# 2021-10-25 SELL ORDER EXECUTED for BTCUSDT: Price: 60852.22, Value: 10213.83, Comm: 6.46
# 2021-11-09 BUY ORDER PLACED
# 2021-11-10 BUY ORDER EXECUTED for BTCUSDT: Price: 66947.67, Value: 12630.47, Comm 6.32
# 2021-11-11 SELL ORDER EXECUTED for BTCUSDT: Price: 64882.42, Value: 12630.47, Comm: 6.12
# 2021-12-05 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 13631.783297743332
#
# Finished backtest 33 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 34/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-10-14 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2021-05-02 BACKTEST STARTING
# 2021-05-02 BUY ORDER PLACED
# 2021-05-03 BUY ORDER EXECUTED for BTCUSDT: Price: 56578.21, Value: 9000.00, Comm 4.50
# 2021-05-13 SELL ORDER EXECUTED for BTCUSDT: Price: 49537.15, Value: 9000.00, Comm: 3.94
# 2021-06-01 BUY ORDER PLACED
# 2021-06-02 BUY ORDER EXECUTED for BTCUSDT: Price: 36694.85, Value: 7984.76, Comm 3.99
# 2021-09-16 SELL ORDER EXECUTED for BTCUSDT: Price: 48121.40, Value: 7984.76, Comm: 5.24
# 2021-10-01 BUY ORDER PLACED
# 2021-10-02 BUY ORDER EXECUTED for BTCUSDT: Price: 48141.60, Value: 10213.83, Comm 5.11
# 2021-10-25 SELL ORDER EXECUTED for BTCUSDT: Price: 60852.22, Value: 10213.83, Comm: 6.46
# 2021-11-09 BUY ORDER PLACED
# 2021-11-10 BUY ORDER EXECUTED for BTCUSDT: Price: 66947.67, Value: 12630.47, Comm 6.32
# 2021-11-11 SELL ORDER EXECUTED for BTCUSDT: Price: 64882.42, Value: 12630.47, Comm: 6.12
# 2021-12-05 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 13631.783297743332
#
# Finished backtest 34 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 35/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-10-14 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2021-05-02 BACKTEST STARTING
# 2021-05-02 BUY ORDER PLACED
# 2021-05-03 BUY ORDER EXECUTED for BTCUSDT: Price: 56578.21, Value: 9000.00, Comm 4.50
# 2021-05-13 SELL ORDER EXECUTED for BTCUSDT: Price: 49537.15, Value: 9000.00, Comm: 3.94
# 2021-06-01 BUY ORDER PLACED
# 2021-06-02 BUY ORDER EXECUTED for BTCUSDT: Price: 36694.85, Value: 7984.76, Comm 3.99
# 2021-09-16 SELL ORDER EXECUTED for BTCUSDT: Price: 48121.40, Value: 7984.76, Comm: 5.24
# 2021-10-01 BUY ORDER PLACED
# 2021-10-02 BUY ORDER EXECUTED for BTCUSDT: Price: 48141.60, Value: 10213.83, Comm 5.11
# 2021-10-25 SELL ORDER EXECUTED for BTCUSDT: Price: 60852.22, Value: 10213.83, Comm: 6.46
# 2021-11-09 BUY ORDER PLACED
# 2021-11-10 BUY ORDER EXECUTED for BTCUSDT: Price: 66947.67, Value: 12630.47, Comm 6.32
# 2021-11-11 SELL ORDER EXECUTED for BTCUSDT: Price: 64882.42, Value: 12630.47, Comm: 6.12
# 2021-12-05 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 13631.783297743332
#
# Finished backtest 35 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# =======================================
# Starting backtest 36/162 with 1 run(s)
#
# =======================================
# Adding strategy datafeeds
# 2020-10-14 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2021-05-02 BACKTEST STARTING
# 2021-05-02 BUY ORDER PLACED
# 2021-05-03 BUY ORDER EXECUTED for BTCUSDT: Price: 56578.21, Value: 9000.00, Comm 4.50
# 2021-05-13 SELL ORDER EXECUTED for BTCUSDT: Price: 49537.15, Value: 9000.00, Comm: 3.94
# 2021-06-01 BUY ORDER PLACED
# 2021-06-02 BUY ORDER EXECUTED for BTCUSDT: Price: 36694.85, Value: 7984.76, Comm 3.99
# 2021-09-16 SELL ORDER EXECUTED for BTCUSDT: Price: 48121.40, Value: 7984.76, Comm: 5.24
# 2021-10-01 BUY ORDER PLACED
# 2021-10-02 BUY ORDER EXECUTED for BTCUSDT: Price: 48141.60, Value: 10213.83, Comm 5.11
# 2021-10-25 SELL ORDER EXECUTED for BTCUSDT: Price: 60852.22, Value: 10213.83, Comm: 6.46
# 2021-11-09 BUY ORDER PLACED
# ...
# Adding strategy datafeeds
# 2023-02-12 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-02-12 BACKTEST STARTING
# 2023-02-12 BUY ORDER PLACED
# 2023-02-13 BUY ORDER EXECUTED for BTCUSDT: Price: 21782.37, Value: 8999.52, Comm 4.50
# 2023-09-17 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 11955.983248590448
#
# Finished backtest 138 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 139/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-02-12 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-02-12 BACKTEST STARTING
# 2023-02-12 BUY ORDER PLACED
# 2023-02-13 BUY ORDER EXECUTED for BTCUSDT: Price: 21782.37, Value: 8999.52, Comm 4.50
# 2023-09-17 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 11955.983248590448
#
# Finished backtest 139 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 140/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-02-12 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-02-12 BACKTEST STARTING
# 2023-02-12 BUY ORDER PLACED
# 2023-02-13 BUY ORDER EXECUTED for BTCUSDT: Price: 21782.37, Value: 8999.52, Comm 4.50
# 2023-09-17 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 11955.983248590448
#
# Finished backtest 140 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 141/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-02-12 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-02-12 BACKTEST STARTING
# 2023-02-12 BUY ORDER PLACED
# 2023-02-13 BUY ORDER EXECUTED for BTCUSDT: Price: 21782.37, Value: 8999.52, Comm 4.50
# 2023-09-17 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 11955.983248590448
#
# Finished backtest 141 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 142/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-02-12 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-02-12 BACKTEST STARTING
# 2023-02-12 BUY ORDER PLACED
# 2023-02-13 BUY ORDER EXECUTED for BTCUSDT: Price: 21782.37, Value: 8999.52, Comm 4.50
# 2023-09-17 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 11955.983248590448
#
# Finished backtest 142 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 143/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-02-12 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-02-12 BACKTEST STARTING
# 2023-02-12 BUY ORDER PLACED
# 2023-02-13 BUY ORDER EXECUTED for BTCUSDT: Price: 21782.37, Value: 8999.52, Comm 4.50
# 2023-09-17 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 11955.983248590448
#
# Finished backtest 143 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 144/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-02-12 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-02-12 BACKTEST STARTING
# 2023-02-12 BUY ORDER PLACED
# 2023-02-13 BUY ORDER EXECUTED for BTCUSDT: Price: 21782.37, Value: 8999.52, Comm 4.50
# 2023-09-17 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 11955.983248590448
#
# Finished backtest 144 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 145/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-09-17 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-09-17 BACKTEST STARTING
# 2023-09-17 BUY ORDER PLACED
# 2023-09-18 BUY ORDER EXECUTED for BTCUSDT: Price: 26527.50, Value: 9000.00, Comm 4.50
# 2024-04-21 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 23028.11595396628
#
# Finished backtest 145 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 146/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-09-17 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-09-17 BACKTEST STARTING
# 2023-09-17 BUY ORDER PLACED
# 2023-09-18 BUY ORDER EXECUTED for BTCUSDT: Price: 26527.50, Value: 9000.00, Comm 4.50
# 2024-04-21 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 23028.11595396628
#
# Finished backtest 146 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 147/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-09-17 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-09-17 BACKTEST STARTING
# 2023-09-17 BUY ORDER PLACED
# 2023-09-18 BUY ORDER EXECUTED for BTCUSDT: Price: 26527.50, Value: 9000.00, Comm 4.50
# 2024-04-21 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 23028.11595396628
#
# Finished backtest 147 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 148/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-09-17 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-09-17 BACKTEST STARTING
# 2023-09-17 BUY ORDER PLACED
# 2023-09-18 BUY ORDER EXECUTED for BTCUSDT: Price: 26527.50, Value: 9000.00, Comm 4.50
# 2024-04-21 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 23028.11595396628
#
# Finished backtest 148 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 149/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-09-17 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-09-17 BACKTEST STARTING
# 2023-09-17 BUY ORDER PLACED
# 2023-09-18 BUY ORDER EXECUTED for BTCUSDT: Price: 26527.50, Value: 9000.00, Comm 4.50
# 2024-04-21 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 23028.11595396628
#
# Finished backtest 149 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 150/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-09-17 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-09-17 BACKTEST STARTING
# 2023-09-17 BUY ORDER PLACED
# 2023-09-18 BUY ORDER EXECUTED for BTCUSDT: Price: 26527.50, Value: 9000.00, Comm 4.50
# 2024-04-21 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 23028.11595396628
#
# Finished backtest 150 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 151/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-09-17 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-09-17 BACKTEST STARTING
# 2023-09-17 BUY ORDER PLACED
# 2023-09-18 BUY ORDER EXECUTED for BTCUSDT: Price: 26527.50, Value: 9000.00, Comm 4.50
# 2024-04-21 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 23028.11595396628
#
# Finished backtest 151 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 152/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-09-17 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-09-17 BACKTEST STARTING
# 2023-09-17 BUY ORDER PLACED
# 2023-09-18 BUY ORDER EXECUTED for BTCUSDT: Price: 26527.50, Value: 9000.00, Comm 4.50
# 2024-04-21 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 23028.11595396628
#
# Finished backtest 152 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 153/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2023-09-17 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2023-09-17 BACKTEST STARTING
# 2023-09-17 BUY ORDER PLACED
# 2023-09-18 BUY ORDER EXECUTED for BTCUSDT: Price: 26527.50, Value: 9000.00, Comm 4.50
# 2024-04-21 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 23028.11595396628
#
# Finished backtest 153 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 154/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2024-04-21 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2024-04-21 BACKTEST STARTING
# 2024-04-21 BUY ORDER PLACED
# 2024-04-22 BUY ORDER EXECUTED for BTCUSDT: Price: 64941.15, Value: 9000.00, Comm 4.50
# 2024-11-24 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 14563.17411725847
#
# Finished backtest 154 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 155/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2024-04-21 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2024-04-21 BACKTEST STARTING
# 2024-04-21 BUY ORDER PLACED
# 2024-04-22 BUY ORDER EXECUTED for BTCUSDT: Price: 64941.15, Value: 9000.00, Comm 4.50
# 2024-11-24 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 14563.17411725847
#
# Finished backtest 155 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 156/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2024-04-21 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2024-04-21 BACKTEST STARTING
# 2024-04-21 BUY ORDER PLACED
# 2024-04-22 BUY ORDER EXECUTED for BTCUSDT: Price: 64941.15, Value: 9000.00, Comm 4.50
# 2024-11-24 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 14563.17411725847
#
# Finished backtest 156 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 157/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2024-04-21 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2024-04-21 BACKTEST STARTING
# 2024-04-21 BUY ORDER PLACED
# 2024-04-22 BUY ORDER EXECUTED for BTCUSDT: Price: 64941.15, Value: 9000.00, Comm 4.50
# 2024-11-24 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 14563.17411725847
#
# Finished backtest 157 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 158/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2024-04-21 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2024-04-21 BACKTEST STARTING
# 2024-04-21 BUY ORDER PLACED
# 2024-04-22 BUY ORDER EXECUTED for BTCUSDT: Price: 64941.15, Value: 9000.00, Comm 4.50
# 2024-11-24 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 14563.17411725847
#
# Finished backtest 158 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 159/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2024-04-21 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2024-04-21 BACKTEST STARTING
# 2024-04-21 BUY ORDER PLACED
# 2024-04-22 BUY ORDER EXECUTED for BTCUSDT: Price: 64941.15, Value: 9000.00, Comm 4.50
# 2024-11-24 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 14563.17411725847
#
# Finished backtest 159 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 160/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2024-04-21 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2024-04-21 BACKTEST STARTING
# 2024-04-21 BUY ORDER PLACED
# 2024-04-22 BUY ORDER EXECUTED for BTCUSDT: Price: 64941.15, Value: 9000.00, Comm 4.50
# 2024-11-24 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 14563.17411725847
#
# Finished backtest 160 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 161/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2024-04-21 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2024-04-21 BACKTEST STARTING
# 2024-04-21 BUY ORDER PLACED
# 2024-04-22 BUY ORDER EXECUTED for BTCUSDT: Price: 64941.15, Value: 9000.00, Comm 4.50
# 2024-11-24 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 14563.17411725847
#
# Finished backtest 161 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
#
# ========================================
# Starting backtest 162/162 with 1 run(s)
#
# ========================================
# Adding strategy datafeeds
# 2024-04-21 00:00:00
# Added all datafeeds
# Strategy added as single backtest
# Initialising Strategy
# 2024-04-21 BACKTEST STARTING
# 2024-04-21 BUY ORDER PLACED
# 2024-04-22 BUY ORDER EXECUTED for BTCUSDT: Price: 64941.15, Value: 9000.00, Comm 4.50
# 2024-11-24 BACKTEST ENDING
#
# Start Portfolio Value: 10000
# Final Portfolio Value: 14563.17411725847
#
# Finished backtest 162 of 162
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl
# Saving BacktestCollection to Main_collection\pkl\collection.pkl
# ✅ Saved collection to Main_collection\pkl\collection.pkl

# %%
main.summarize_in_groups(period_key='test')
# Out:
#                                                              max_drawdown  \
#                                                                       max
# input_collection_name period_key backtest_class parameter_id
# wfo                   test       buy_hold       buy_hold-1      56.601326
#                                  strat_03       strat_03-12     35.869917
#
#                                                                          \
#                                                                    mean
# input_collection_name period_key backtest_class parameter_id
# wfo                   test       buy_hold       buy_hold-1    33.532720
#                                  strat_03       strat_03-12   16.020744
#
#                                                                          \
#                                                                     std
# input_collection_name period_key backtest_class parameter_id
# wfo                   test       buy_hold       buy_hold-1    13.575190
#                                  strat_03       strat_03-12   10.308484
#
#                                                                     cagr  \
#                                                                     mean
# input_collection_name period_key backtest_class parameter_id
# wfo                   test       buy_hold       buy_hold-1    187.385556
#                                  strat_03       strat_03-12    98.178889
#
#                                                                      \
#                                                              median
# input_collection_name period_key backtest_class parameter_id
# wfo                   test       buy_hold       buy_hold-1    13.09
#                                  strat_03       strat_03-12   68.10
#
#                                                                           \
#                                                                      std
# input_collection_name period_key backtest_class parameter_id
# wfo                   test       buy_hold       buy_hold-1    420.058642
#                                  strat_03       strat_03-12   167.858568
#
#                                                              sharperatio  \
#                                                                     mean
# input_collection_name period_key backtest_class parameter_id
# wfo                   test       buy_hold       buy_hold-1      1.000000
#                                  strat_03       strat_03-12     1.343333
#
#                                                                         \
#                                                                    std
# input_collection_name period_key backtest_class parameter_id
# wfo                   test       buy_hold       buy_hold-1    1.648185
#                                  strat_03       strat_03-12   1.289625
#
#                                                              time_in_market  \
#                                                                        mean
# input_collection_name period_key backtest_class parameter_id
# wfo                   test       buy_hold       buy_hold-1       100.000000
#                                  strat_03       strat_03-12       42.037778
#
#
#                                                                     std
# input_collection_name period_key backtest_class parameter_id
# wfo                   test       buy_hold       buy_hold-1     0.000000
#                                  strat_03       strat_03-12   24.160939

# %%
main.summarize_in_groups(period_key='train', parameter_id=['strat_03-12', 'buy_hold-1'])
# Out:
#                                                              max_drawdown  \
#                                                                       max
# input_collection_name period_key backtest_class parameter_id
# wfo                   train      buy_hold       buy_hold-1      71.680455
#                                  strat_03       strat_03-12     40.857079
#
#                                                                          \
#                                                                    mean
# input_collection_name period_key backtest_class parameter_id
# wfo                   train      buy_hold       buy_hold-1    53.868827
#                                  strat_03       strat_03-12   27.019361
#
#                                                                          \
#                                                                     std
# input_collection_name period_key backtest_class parameter_id
# wfo                   train      buy_hold       buy_hold-1    15.420983
#                                  strat_03       strat_03-12   11.937463
#
#                                                                    cagr  \
#                                                                    mean
# input_collection_name period_key backtest_class parameter_id
# wfo                   train      buy_hold       buy_hold-1    72.633333
#                                  strat_03       strat_03-12   69.134444
#
#                                                                      \
#                                                              median
# input_collection_name period_key backtest_class parameter_id
# wfo                   train      buy_hold       buy_hold-1    23.98
#                                  strat_03       strat_03-12   42.21
#
#                                                                           \
#                                                                      std
# input_collection_name period_key backtest_class parameter_id
# wfo                   train      buy_hold       buy_hold-1    132.131354
#                                  strat_03       strat_03-12    88.732081
#
#                                                              sharperatio  \
#                                                                     mean
# input_collection_name period_key backtest_class parameter_id
# wfo                   train      buy_hold       buy_hold-1      0.767778
#                                  strat_03       strat_03-12     1.185556
#
#                                                                         \
#                                                                    std
# input_collection_name period_key backtest_class parameter_id
# wfo                   train      buy_hold       buy_hold-1    1.181723
#                                  strat_03       strat_03-12   0.952577
#
#                                                              time_in_market  \
#                                                                        mean
# input_collection_name period_key backtest_class parameter_id
# wfo                   train      buy_hold       buy_hold-1       100.000000
#                                  strat_03       strat_03-12       36.713333
#
#
#                                                                     std
# input_collection_name period_key backtest_class parameter_id
# wfo                   train      buy_hold       buy_hold-1     0.000000
#                                  strat_03       strat_03-12   20.207359
